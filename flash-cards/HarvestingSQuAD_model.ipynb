# %% [markdown]
# # Flash Cards
#
#
#
# *   Muhammed Görkem KOLA - 2200765032
# *   İlkim İclal Aydoğan - 21992814

# %% [markdown]
# ## Reading Data

# %%
# !pip install transformers
# !pip install datasets
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 50.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 53.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.25.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 27.7 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (4.0.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: xxhash, urllib3, multiprocess, responses, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.8.0 multiprocess-0.70.14 responses-0.18.0 urllib3-1.26.14 xxhash-3.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.9-py2.py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (7.1.2)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 24.8 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb) (6.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from wandb) (4.4.0)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.25.1)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.13.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 KB 21.9 MB/s eta 0:00:00
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=c82b94d2150d4ebb4437e0deac4ed43b79a0e708476031bbc5aa9738aafcd769
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.30 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.13.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.13.9

# %%
# Import the 'wandb' module and log in to the W&B server
import wandb
wandb.init(project="flash-cards", entity="colomar")

# Set the WANDB_PROJECT environment variable to 'flash-cards'
# %env WANDB_PROJECT=flash-cards
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668872733333253, max=1.0…
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/content/wandb/run-20230113_085022-ivd1cqq8</code>
# Syncing run <strong><a href="https://wandb.ai/colomar/flash-cards/runs/ivd1cqq8" target="_blank">valiant-field-86</a></strong> to <a href="https://wandb.ai/colomar/flash-cards" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/colomar/flash-cards" target="_blank">https://wandb.ai/colomar/flash-cards</a>
#  View run at <a href="https://wandb.ai/colomar/flash-cards/runs/ivd1cqq8" target="_blank">https://wandb.ai/colomar/flash-cards/runs/ivd1cqq8</a>
# env: WANDB_PROJECT=flash-cards

# %%
# Import the 'torch', 'datasets', and 'transformers' modules
import torch
from datasets import load_dataset, load_metric, list_metrics, Dataset, concatenate_datasets, Sequence, Features, Value
import transformers
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, DataCollator, T5ForConditionalGeneration, T5TokenizerFast, TrainingArguments, Trainer
import json

# Import the 'Dict', 'List', and 'Optional' types from the 'typing' module
from typing import Dict, List, Optional

# Import the 'dataclasses' and 'field' modules
import dataclasses
from dataclasses import dataclass, field

# Import the 'logging', 'os', and 'sys' modules
import logging
import os
import sys

# Import the 'numpy', 'torch', and 'wandb' modules
import numpy as np
import torch
import wandb

# Import the 'notebook_login' function from the 'huggingface_hub' module
from huggingface_hub import notebook_login

# Import the 'drive' function from the 'google.cplab' package
from google.colab import drive

# %%
def read_data(path: str):
    """
    Read data in the SQuAD v2 format from a file and create a dataset object from it.
    Args:
    - path: the path to the file containing the data
    Returns:
    - A dataset object containing the data
    """
    # Check if the file exists and is readable
    if not os.path.isfile(path) or not os.access(path, os.R_OK):
        raise FileNotFoundError(f"File '{path}' not found or not readable")
    
    # Open the file and read the data as a JSON object
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
        data = data["data"]
        
        # Initialize an empty list to store the dictionaries representing the examples
        dicts = []
        
        # Iterate over the data points in the JSON object
        for dt in data:
            # Extract the 'paragraphs' and 'title' fields from the current data point
            paragraphs, title = dt.values()
            
            # Iterate over the paragraphs in the current data point
            for x in paragraphs[:5]:
                # Extract the 'context' and 'qas' fields from the current paragraph
                context, qas = x.values()
                
                # Iterate over the questions in the current paragraph, up to a maximum of 10
                for aiq in qas[:5]:
                    # Extract the 'answers', '_id', and 'question' fields from the current question
                    answers, _id, question = aiq.values()
                    
                    # Initialize a dictionary for storing the answers
                    ans = {
                        "answer_start":[],
                        "text":[],
                    }
                    
                    # Iterate over the answers and append the text and starting position of each answer to the corresponding lists in 'ans'
                    for a in answers:
                        ans["text"].append(a["text"])
                        ans["answer_start"].append(a["answer_start"])
                    
                    # Create a dictionary representing the current example and append it to the list of dictionaries
                    dicts.append({
                        "id":str(_id),
                        "title":title,
                        "context":context,
                        "question":question,
                        "answers": ans
                    })
        
        # Create a dataset object from the list of dictionaries using the 'from_list' method
        data = Dataset.from_list(dicts)
        return data

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change the current working directory to '/content/drive/MyDrive/dataset'
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# ### New Section

# %%
# Read the training data from the 'train.json' file and create a dataset object from it
Htrain_data = read_data("train.json")

# Read the validation data from the 'dev.json' file and create a dataset object from it
Hvalid_data = read_data("dev.json")

# %%
# Harvesting Train and Validation datasets
Htrain_data, Hvalid_data
# Out:
# (Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 128619
#  }), Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 1666
#  }))

# %%
# squad-v2 dataset
dataset = load_dataset("squad_v2")
# Out:
# WARNING:datasets.builder:Found cached dataset squad_v2 (/root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Create a dataset object from the 'train' portion of the 'dataset' dictionary and assign it to the 'Strain_data' variable
Strain_data = Dataset.from_dict(dataset["train"][:])

# Create a dataset object from the 'validation' portion of the 'dataset' dictionary and assign it to the 'Svalid_data' variable
Svalid_data = Dataset.from_dict(dataset["validation"][:])

# %%
# squad-v2 Train and Validation datasets
Strain_data, Svalid_data
# Out:
# (Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 130319
#  }), Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 11873
#  }))

# %%
# Concatenate the 'Strain_data' and 'Htrain_data' datasets and assign the resulting dataset to the 'train_dataset' variable
train_dataset = concatenate_datasets([Strain_data, Htrain_data])

# Concatenate the 'Svalid_data' and 'Hvalid_data' datasets and assign the resulting dataset to the 'valid_dataset' variable
valid_dataset = concatenate_datasets([Svalid_data, Hvalid_data])

# %%
# Train and Validation datasets
train_dataset, valid_dataset
# Out:
# (Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 258938
#  }), Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 13539
#  }))

# %% [markdown]
# ### TOKENIZE DATA

# %%
# Create a T5 model using the 't5-small' pre-trained model and assign it to the 'model' variable
model = T5ForConditionalGeneration.from_pretrained("t5-small")

# Create a T5 tokenizer using the 't5-small' pre-trained model and assign it to the 'tokenizer' variable
tokenizer = T5TokenizerFast.from_pretrained("t5-small")
# Out:
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
# Set the value of the 'sep_token' attribute of the tokenizer to '<sep>'
tokenizer.sep_token = '<sep>'

# Add the '<sep>' token to the vocabulary of the tokenizer
tokenizer.add_tokens(['<sep>'])

# Resize the token embeddings of the model to match the size of the vocabulary of the tokenizer
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(32101, 512)

# %%
def convert_to_features(example_batch):
    """
    Encode a batch of examples as input IDs and attention masks using a tokenizer.
    Args:
    - example_batch: a batch of examples, where each example is a dictionary with 'context' and 'question' fields
    Returns:
    - A dictionary with input IDs, attention masks, labels, and decoder attention masks
    """
    # Encode the 'context' field of each example in the batch using the tokenizer
    input_encodings = tokenizer.batch_encode_plus(example_batch['context'],
                                                  max_length=512,
                                                  add_special_tokens=True,
                                                  truncation=True,
                                                  pad_to_max_length=True)
    
    # Encode the 'question' field of each example in the batch using the tokenizer
    target_encodings = tokenizer.batch_encode_plus(example_batch['question'],
                                                   max_length=64,
                                                   add_special_tokens=True,
                                                   truncation=True, pad_to_max_length=True)

    # Combine the input IDs and attention masks into a dictionary
    encodings = {
        'input_ids': input_encodings['input_ids'],
        'attention_mask': input_encodings['attention_mask'],
        'labels': target_encodings['input_ids'],
        'decoder_attention_mask': target_encodings['attention_mask']
    }

    return encodings

def add_eos_examples(example):
    """
    Append the end-of-sequence token to the 'context' and 'question' fields of an example.
    Args:
    - example: an example, represented as a dictionary with 'context' and 'question' fields
    Returns:
    - The modified example
    """
    # Append the end-of-sequence token to the 'context' and 'question' fields
    example['context'] = example['context'] + " </s>"
    example['question'] = example['question'] + " </s>"
    return example

def add_special_tokens(example):
    """
    Replace the "{sep_token}" placeholder in the 'question' field of an example with the special token '<sep>'.
    Args:
    - example: an example, represented as a dictionary with a 'question' field
    Returns:
    - The modified example
    """
    # Replace the "{sep_token}" placeholder with the special token '<sep>'
    example['question'] = example['question'].replace("{sep_token}", '<sep>')
    return example

# %% [markdown]
# ### NO RUN

# %%
# Apply the add_eos_examples function to each example in the train_dataset,
# modifying the examples by adding the "</s>" suffix to the "context" and "question" fields
train_dataset = train_dataset.map(add_eos_examples)

# Apply the add_special_tokens function to each example in the train_dataset,
# modifying the examples by replacing the "{sep_token}" placeholder in the "question" field with "<sep>"
train_dataset = train_dataset.map(add_special_tokens)

# Apply the convert_to_features function to each example in the train_dataset,
# converting the "context" and "question" fields of each example to tokenized tensors using the T5 tokenizer
# and returning a dictionary of input features for the T5 model
train_dataset = train_dataset.map(convert_to_features, batched=True)
# Out:
#   0%|          | 0/258938 [00:00<?, ?ex/s]
#   0%|          | 0/258938 [00:00<?, ?ex/s]
#   0%|          | 0/259 [00:00<?, ?ba/s]
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:2336: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
# Apply the add_eos_examples function to each example in the valid_dataset,
# modifying the examples by adding the "</s>" suffix to the "context" and "question" fields
valid_dataset = valid_dataset.map(add_eos_examples)

# Apply the add_special_tokens function to each example in the valid_dataset,
# modifying the examples by replacing the "{sep_token}" placeholder in the "question" field with "<sep>"
valid_dataset = valid_dataset.map(add_special_tokens)

# Apply the convert_to_features function to each example in the valid_dataset,
# converting the "context" and "question" fields of each example to tokenized tensors using the T5 tokenizer
# and returning a dictionary of input features for the T5 model
valid_dataset = valid_dataset.map(convert_to_features, batched=True)
# Out:
#   0%|          | 0/13539 [00:00<?, ?ex/s]
#   0%|          | 0/13539 [00:00<?, ?ex/s]
#   0%|          | 0/14 [00:00<?, ?ba/s]

# %%
# Define a list of column names to remove from the dataset
columns_removed = ['id', 'title', 'context', 'question', 'answers']

# Define a list of column names to keep in the dataset
columns = ['input_ids', 'attention_mask', 'labels', 'decoder_attention_mask']

# %%
# Remove the specified columns from the 'train_dataset' dataset
train_dataset = train_dataset.remove_columns(columns_removed)

# Remove the specified columns from the 'valid_dataset' dataset
valid_dataset = valid_dataset.remove_columns(columns_removed)

# %% [markdown]
# ### SAVE DATA

# %%
# Set the format of the 'train_dataset' dataset to 'torch'
train_dataset.set_format(type='torch')

# Set the format of the 'valid_dataset' dataset to 'torch'
valid_dataset.set_format(type='torch')

# %%
# Train and Validation datasets
train_dataset, valid_dataset
# Out:
# (Dataset({
#      features: ['input_ids', 'attention_mask', 'labels', 'decoder_attention_mask'],
#      num_rows: 258938
#  }), Dataset({
#      features: ['input_ids', 'attention_mask', 'labels', 'decoder_attention_mask'],
#      num_rows: 13539
#  }))

# %%
# Change the current working directory to the root directory of the filesystem
# %cd ../../../../..
# Out:
# /

# %%
# Save the 'train_dataset' dataset to a file called 'train_dataset.pt'
torch.save(train_dataset, 'train_dataset.pt')

# Save the 'valid_dataset' dataset to a file called 'valid_dataset.pt'
torch.save(valid_dataset, 'valid_dataset.pt')

# %% [markdown]
# ## FINE TUNING

# %%
# A dataclass for formatting the data in a way that is expected by the model's forward method
@dataclass
class T2TDataCollator():
    def __call__(self, batch: List) -> Dict[str, torch.Tensor]:
        """
        Take a list of samples from a Dataset and collate them into a batch.
        Returns:
        A dictionary of tensors
        """
        # Stack the 'input_ids' from each example in the batch
        input_ids = torch.stack([example['input_ids'] for example in batch])
        
        # Stack the 'labels' from each example in the batch, replacing any 0 values with -100
        lm_labels = torch.stack([example['labels'] for example in batch])
        lm_labels[lm_labels == 0] = -100
        
        # Stack the 'attention_mask' from each example in the batch
        attention_mask = torch.stack([example['attention_mask'] for example in batch])
        
        # Stack the 'decoder_attention_mask' from each example in the batch
        decoder_attention_mask = torch.stack([example['decoder_attention_mask'] for example in batch])

        # Return a dictionary of the stacked tensors
        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'labels': lm_labels,
            'decoder_attention_mask': decoder_attention_mask
        }

# %%
# Log in to the Hub
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
# Specify the directory where the model and training artifacts will be saved
output_dir="./models"

# Specify the number of examples per device in a single training batch
per_device_train_batch_size=4

# Specify the number of examples per device in a single evaluation batch
per_device_eval_batch_size=4

# Specify the number of gradient accumulation steps, which determine the actual batch size
# The actual batch size is equal to per_device_train_batch_size * gradient_accumulation_steps * num_devices
gradient_accumulation_steps=16

# Specify the learning rate used in the training process
learning_rate=1e-4

# Specify the number of training epochs
# An epoch is a single pass through the entire training dataset
num_train_epochs=3

# Specify how often to log training progress
logging_steps=100

# Specify the name of the run
# This is useful for distinguishing different runs in tools like Weights & Biases
run_name="flash-cards"

# Specify the evaluation strategy
# Possible values include "epoch" (evaluate after each epoch) and "steps" (evaluate after a certain number of steps)
evaluation_strategy="steps"

# Specify how often to save the model
save_steps=500

# Specify a service to report training progress to
report_to="wandb"

# Specify whether to push the model to the model hub
push_to_hub=True

# Specify the model ID to use when pushing the model to the model hub
push_to_hub_model_id="flash-cards-3"

# %%
training_args = TrainingArguments(
    output_dir = output_dir,
    per_device_train_batch_size = per_device_train_batch_size,
    per_device_eval_batch_size = per_device_eval_batch_size,
    gradient_accumulation_steps = gradient_accumulation_steps,
    learning_rate = learning_rate,
    num_train_epochs = num_train_epochs,
    logging_steps = logging_steps,
    run_name = run_name,
    evaluation_strategy = evaluation_strategy,
    save_steps = save_steps,
    report_to = report_to,
    push_to_hub = push_to_hub,
    push_to_hub_model_id = push_to_hub_model_id
  )
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/training_args.py:1276: FutureWarning: `--push_to_hub_model_id` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_model_id` instead and pass the full repo name to this argument (in this case grkmkola/flash-cards-3).
#   warnings.warn(

# %%
# Initialize our Trainer
trainer = Trainer(
    # Specify the model to train
    model=model,

    # Specify the training arguments
    args=training_args,

    # Specify the training dataset
    train_dataset=train_dataset,

    # Specify the validation dataset
    eval_dataset=valid_dataset,

    # Specify the data collator
    data_collator=T2TDataCollator()
)

# Start training
trainer.train()

# When training is done, push the fine-tuned model to the model hub
trainer.push_to_hub("flash-cards-3")

# Finish the run in Weights & Biases
wandb.finish()
# Out:
# Cloning https://huggingface.co/grkmkola/flash-cards-3 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/grkmkola/flash-cards-3 into local empty directory.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 258938
#   Num Epochs = 3
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 16
#   Total optimization steps = 12135
#   Number of trainable parameters = 60492800
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='37' max='12135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   37/12135 1:26:18 < 497:11:07, 0.01 it/s, Epoch 0.01/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %% [markdown]
# ## TESTING MODEL

# %%
# downloading the model
hfmodel = T5ForConditionalGeneration.from_pretrained("grkmkola/flash-cards-3")
# Out:
# Downloading:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
def question_generate(input_string, **generator_args):
  # Set default generator arguments
  default_generator_args = {
    "max_length": 256,  # maximum number of tokens to generate
    "num_beams": 4,  # number of beams to use when generating text
    "length_penalty": 1.5,  # length penalty to use when generating text
    "no_repeat_ngram_size": 3,  # size of n-grams that the model should not repeat
    "early_stopping": True,  # whether to stop generating text as soon as max length is reached
  }
  
  # Update default generator arguments with provided generator arguments
  generator_args = {**default_generator_args, **generator_args}
  
  # Modify input string to indicate that we want to generate questions
  input_string = "generate questions: " + input_string + " </s>"
  
  # Encode input string as input tokens
  input_ids = tokenizer.encode(input_string, return_tensors="pt",max_length=512,truncation=True)
  
  # Generate text based on input tokens and generator arguments
  res = hfmodel.generate(input_ids, **generator_args)
  
  # Decode and split generated text to obtain list of questions
  output = tokenizer.batch_decode(res, skip_special_tokens=True)
  output = [item.split("<sep>") for item in output]
  
  # Return list of questions as output
  return output

# %%
def run_model(dataset):
  # Generate questions for each data point in the dataset
  generated_questions = [question_generate(data["context"]) for data in dataset]
  
  # Return list of generated questions
  return generated_questions

# %%
# Read the test data from the 'test.json' file and create a dataset object from it
test_data = read_data("/content/drive/MyDrive/Colab Notebooks/test.json")

# %%
# Generate questions for each data point in the test dataset
predictions = run_model(test_data)

# The predictions variable now contains a list of generated questions

# %% [markdown]
# ### BLEU SCORE

# %% [markdown]
# The BLEU (Bilingual Evaluation Understudy) score is a metric used to evaluate the quality of machine-generated translations. It compares the machine-generated translation to one or more reference translations, and calculates a score based on the number of matching n-grams (sequences of n words) between the two. The BLEU score is a standard metric used in the field of natural language processing (NLP), and is often used to compare different machine translation models or to tune the hyperparameters of a machine translation model.

# %%
# Import the sentence_bleu function from the bleu_score module of the nltk.translate package
from nltk.translate.bleu_score import sentence_bleu

# %%
# Compute BLEU scores using different n-grams as the basis for comparison
one_gram_score = np.mean([sentence_bleu(predicted[0], real, weights=(1, 0, 0, 0)) for predicted, real in zip(predictions, test_data["question"])])
two_gram_score = np.mean([sentence_bleu(predicted[0], real, weights=(0, 1, 0, 0)) for predicted, real in zip(predictions,test_data["question"])])
three_gram_score = np.mean([sentence_bleu(predicted[0], real, weights=(0, 0, 1, 0)) for predicted, real in zip(predictions, test_data["question"])])
four_gram_score = np.mean([sentence_bleu(predicted[0], real, weights=(0, 0, 0, 1)) for predicted, real in zip(predictions, test_data["question"])])
cumulative_score = np.mean([sentence_bleu(predicted[0], real, weights=(.25, .25, .25, .25)) for predicted, real in zip(predictions, test_data["question"])])
# Out:
# /usr/local/lib/python3.8/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.8/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
# Print BLEU scores
print("1-gram BLEU score:", one_gram_score)
print("2-gram BLEU score:", two_gram_score)
print("3-gram BLEU score:", three_gram_score)
print("4-gram BLEU score:", four_gram_score)
print("Cumulative BLEU score:", cumulative_score)
# Out:
# 1-gram BLEU score: 0.6320910556473678
# 2-gram BLEU score: 0.413312985156345
# 3-gram BLEU score: 0.3183183804480916
# 4-gram BLEU score: 0.27959201405338496
# Cumulative BLEU score: 0.37140331331327114

# %% [markdown]
# ### METEOR SCORE

# %% [markdown]
# The METEOR score is a metric used to evaluate the quality of machine-generated translations. It compares the machine-generated translation to one or more reference translations, and calculates a score based on the degree of word overlap between the two. The METEOR score is sensitive to word order, and takes into account both exact and stemmed word matches. It is a standard metric used in the field of natural language processing (NLP), and is often used to compare different machine translation models or to tune the hyperparameters of a machine translation model.

# %%
# Import the meteor_score function from the bleu_score module of the nltk.translate.meteor_score package
from nltk.translate.meteor_score import meteor_score

# Import the word_tokenize function from the bleu_score module of the nltk.tokenize package
from nltk.tokenize import word_tokenize

# %%
# Import the nltk package
import nltk

# Download necessary nltk resources
nltk.download("punkt")
nltk.download('omw-1.4')
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Compute average METEOR score for generated questions
meteor = np.mean([meteor_score([word_tokenize(predicted[0][0])], word_tokenize(real)) for predicted, real in zip(predictions, test_data["question"])])

# The meteor variable now contains the average METEOR score for the generated questions

# %%
print("METEOR score:", meteor)
# Out:
# METEOR score: 0.3865935763152301

# %% [markdown]
# ### ROUGE SCORE

# %% [markdown]
# The ROUGE score is a metric used to evaluate the quality of machine-generated translations. It compares the machine-generated translation to one or more reference translations, and calculates a score based on the degree of word overlap between the two. The ROUGE score is sensitive to word order, and takes into account both exact and stemmed word matches. It is a standard metric used in the field of natural language processing (NLP), and is often used to compare different machine translation models or to tune the hyperparameters of a machine translation model.

# %%
# Install the rouge-score package
# !pip install rouge-score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from rouge-score) (1.3.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from rouge-score) (3.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from rouge-score) (1.21.6)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.8/dist-packages (from rouge-score) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk->rouge-score) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->rouge-score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->rouge-score) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->rouge-score) (7.1.2)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24955 sha256=1c59905cbc80514e7d3a9fd6045b97cf694292827baaf3f1506d9df09f6fea86
#   Stored in directory: /root/.cache/pip/wheels/24/55/6f/ebfc4cb176d1c9665da4e306e1705496206d08215c1acd9dde
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
# Import the RougeScorer class from the rouge_scorer module of the rouge_score package
from rouge_score.rouge_scorer import RougeScorer

# %%
# Create an instance of the RougeScorer class with the 'rouge1' and 'rougeL' metrics
scorer = RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)

# %%
# Compute ROUGE scores for generated questions and reference questions
scores = [scorer.score(predicted[0][0], real) for predicted, real in zip(predictions[::], test_data["question"])]

# The scores variable now contains a list of dictionaries, each dictionary containing the ROUGE scores for a pair of generated question and reference question

# %%
# Calculate the mean ROUGE-1 and ROUGE-L scores
rouge1_score = np.mean([score["rouge1"] for score in scores])
rougeL_score = np.mean([score["rougeL"] for score in scores])

# %%
print("ROUGE1 score:", rouge1_score)
print("ROUGEL score:", rougeL_score)
# Out:
# ROUGE1 score: 0.4217890040220748
# ROUGEL score: 0.40956531222299386

# %% [markdown]
# ### Precision, Recall and F1 Scores

# %% [markdown]
# Precision, recall, and F1 score are evaluation metrics used to measure the quality of machine-generated translations. They are commonly used in the field of natural language processing (NLP).
#
# - **Precision** is a measure of the fraction of the machine-generated translation that is correct. It is calculated as the number of correctly translated words divided by the total number of words in the machine-generated translation. A higher precision score indicates a higher quality translation.
# - **Recall** is a measure of the fraction of the reference translation that is correctly translated. It is calculated as the number of correctly translated words divided by the total number of words in the reference translation. A higher recall score indicates a higher quality translation.
# - **F1 score** is the harmonic mean of precision and recall, and is a measure of the overall quality of the machine-generated translation. It is calculated as the harmonic mean of precision and recall, using the following formula:
#   F1 = 2 * (precision * recall) / (precision + recall)
#   A higher F1 score indicates a higher quality translation.
#
# In general, a machine-generated translation with high precision will have fewer errors, but may not cover all the content of the reference translation. On the other hand, a machine-generated translation with high recall will cover more of the content of the reference translation, but may have more errors. The F1 score takes both precision and recall into account and provides a balance between the two.

# %%
# Compute mean F1, recall, and precision for the ROUGE-1 metric
rouge1_f1 = np.mean([score["rouge1"].fmeasure for score in scores])
rouge1_recall = np.mean([score["rouge1"].recall for score in scores])
rouge1_precision = np.mean([score["rouge1"].precision for score in scores])

# Compute mean F1, recall, and precision for the ROUGE-L metric
rougeL_f1 = np.mean([score["rougeL"].fmeasure for score in scores])
rougeL_recall = np.mean([score["rougeL"].recall for score in scores])
rougeL_precision = np.mean([score["rougeL"].precision for score in scores])

# The rouge1_f1, rouge1_recall, rouge1_precision, rougeL_f1, rougeL_recall, and rougeL_precision variables now contain the mean F1, recall, and precision for the ROUGE-1 and ROUGE-L metrics, respectively

# %%
print("Mean F1 score (ROUGE-1):", rouge1_f1)
print("Mean recall (ROUGE-1):", rouge1_recall)
print("Mean precision (ROUGE-1):", rouge1_precision)

print("Mean F1 score (ROUGE-L):", rougeL_f1)
print("Mean recall (ROUGE-L):", rougeL_recall)
print("Mean precision (ROUGE-L):", rougeL_precision)
# Out:
# Mean F1 score (ROUGE-1): 0.4144779737671685
# Mean recall (ROUGE-1): 0.4196291158956565
# Mean precision (ROUGE-1): 0.4312599224033995
# Mean F1 score (ROUGE-L): 0.4024715892889253
# Mean recall (ROUGE-L): 0.40724348377940056
# Mean precision (ROUGE-L): 0.41898086360065556

# %%
test_data
# Out:
# Dataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_rows: 1587
# })

# %%
predictions
# Out:
# [[['what is the oldest federal cultural institution in the united states?']],
#  [['what is the oldest federal cultural institution in the united states?']],
#  [['what is the oldest federal cultural institution in the united states?']],
#  [['what is the oldest federal cultural institution in the united states?']],
#  [['what is the oldest federal cultural institution in the united states?']],
#  [['what is the largest library in the world?']],
#  [['what is the largest library in the world?']],
#  [['what is the largest library in the world?']],
#  [['when did the library of congress move to washington?']],
#  [['when did the library of congress move to washington?']],
#  [['when did the library of congress move to washington?']],
#  [['when did the library of congress move to washington?']],
#  [['when did the library of congress move to washington?']],
#  [['When did the Library of Congress begin to grow rapidly?']],
#  [['When did the Library of Congress begin to grow rapidly?']],
#  [['what were the stories built underground of steel and cast iron stacks?']],
#  [['what were the stories built underground of steel and cast iron stacks?']],
#  [['how many inhabitants are in the czech republic?']],
#  [['how many inhabitants are in the czech republic?']],
#  [['how many inhabitants are in the czech republic?']],
#  [['how many inhabitants are in the czech republic?']],
#  [['when was the duchy of bohemia formed?']],
#  [['when was the duchy of bohemia formed?']],
#  [['when was the duchy of bohemia formed?']],
#  [['when was the duchy of bohemia formed?']],
#  [['when was the duchy of bohemia formed?']],
#  [['in what year was the crown of bohemia integrated?']],
#  [['in what year was the crown of bohemia integrated?']],
#  [['in what year was the crown of bohemia integrated?']],
#  [['in what year was the crown of bohemia integrated?']],
#  [['in what year was the crown of bohemia integrated?']],
#  [['when was the czech part of tschechoslovakia liberated?']],
#  [['when was the czech part of tschechoslovakia liberated?']],
#  [['when was the czech part of tschechoslovakia liberated?']],
#  [['in what year did the czech republic join nato?']],
#  [['in what year did the czech republic join nato?']],
#  [['in what year did the czech republic join nato?']],
#  [['in what year did the czech republic join nato?']],
#  [['in what year did the czech republic join nato?']],
#  [['where is egypt located?']],
#  [['where is egypt located?']],
#  [['where is egypt located?']],
#  [['what are some of the earliest developments of ancient egypt?']],
#  [['what are some of the earliest developments of ancient egypt?']],
#  [['what are some of the earliest developments of ancient egypt?']],
#  [['how many inhabitants are in egypt?']],
#  [['how many inhabitants are in egypt?']],
#  [['what is modern egypt considered to be?']],
#  [['what is modern egypt considered to be?']],
#  [['what is modern egypt considered to be?']],
#  [['what is modern egypt considered to be?']],
#  [['what is the oldest attestation of this name for egypt?']],
#  [['what is the oldest attestation of this name for egypt?']],
#  [['what is the oldest attestation of this name for egypt?']],
#  [['what is the oldest attestation of this name for egypt?']],
#  [['what is the oldest attestation of this name for egypt?']],
#  [['what is the sovereign state in east asia?']],
#  [['what is the sovereign state in east asia?']],
#  [['what is the sovereign state in east asia?']],
#  [['what is the sovereign state in east asia?']],
#  [['what percentage of south koreans live in high-rises concentrated in the seoul capital area?']],
#  [['what percentage of south koreans live in high-rises concentrated in the seoul capital area?']],
#  [['when did the earliest korean pottery begin?']],
#  [['when did the earliest korean pottery begin?']],
#  [['when did the earliest korean pottery begin?']],
#  [['when did the earliest korean pottery begin?']],
#  [['when did the earliest korean pottery begin?']],
#  [['what percentage of the world economy does south korea have?']],
#  [['what percentage of the world economy does south korea have?']],
#  [['what percentage of the world economy does south korea have?']],
#  [["what is south korea's most developed country?"]],
#  [['what is the name of the phrase that is translated as a school?']],
#  [['what is the name of the phrase that is translated as a school?']],
#  [['what is the name of the phrase that is translated as a school?']],
#  [['when was the university of bologna founded?']],
#  [['when was the university of bologna founded?']],
#  [['when was the university of bologna founded?']],
#  [['when was the university of bologna founded?']],
#  [['when was the university of bologna founded?']],
#  [['what was a common epithet for ceres?']],
#  [['what was a common epithet for ceres?']],
#  [['what was a common epithet for ceres?']],
#  [['what was a common epithet for ceres?']],
#  [["who began using an emblem for the university's press?"]],
#  [["who began using an emblem for the university's press?"]],
#  [["who began using an emblem for the university's press?"]],
#  [["who began using an emblem for the university's press?"]],
#  [["who began using an emblem for the university's press?"]],
#  [['what is the main student government known as?']],
#  [['what is the main student government known as?']],
#  [['what is the main student government known as?']],
#  [['where is pakistan located?']],
#  [['where is pakistan located?']],
#  [['where is pakistan located?']],
#  [['where is pakistan located?']],
#  [['what is the name of the cradle that constitutes pakistan?']],
#  [['what is the name of the cradle that constitutes pakistan?']],
#  [['what is the name of the cradle that constitutes pakistan?']],
#  [['what is the name of the cradle that constitutes pakistan?']],
#  [['what is the name of the cradle that constitutes pakistan?']],
#  [['who led the pakistan movement?']],
#  [['who led the pakistan movement?']],
#  [['who led the pakistan movement?']],
#  [['who led the pakistan movement?']],
#  [['who led the pakistan movement?']],
#  [["what is pakistan's economy?"]],
#  [['what are some of the challenges of pakistan?']],
#  [['what are some of the challenges of pakistan?']],
#  [['what is the name of the scientific agency of the united states?']],
#  [['what is the name of the scientific agency of the united states?']],
#  [['what is the name of the scientific agency of the united states?']],
#  [['what is the name of the scientific agency of the united states?']],
#  [['what is the name of the scientific agency of the united states?']],
#  [['where is the usg headquartered?']],
#  [['where is the usg headquartered?']],
#  [['where is the usg headquartered?']],
#  [['what is the current motto of the usg?']],
#  [['what is the current motto of the usg?']],
#  [['what is the current motto of the usg?']],
#  [['when was the usg created?']],
#  [['when was the usg created?']],
#  [['when was the usg created?']],
#  [['when was the usg created?']],
#  [['when was the legislation discontinued?']],
#  [['when was the legislation discontinued?']],
#  [["what are the names of the term  county ''?"]],
#  [["what are the names of the term  county ''?"]],
#  [['what are the administrative subdivisions of a state?']],
#  [['what are the administrative subdivisions of a state?']],
#  [['what are the administrative subdivisions of a state?']],
#  [['what is the largest unincorporated county seat in the united states?']],
#  [['what is the name of the county that lists both biloxi and golfport?']],
#  [['what is the name of the county that lists both biloxi and golfport?']],
#  [['what is the name of the county that lists both biloxi and golfport?']],
#  [['how many counties are there in 11 states?']],
#  [['how many counties are there in 11 states?']],
#  [['what is the basic unit of biological classification?']],
#  [['what is the basic unit of biological classification?']],
#  [['what is the basic unit of biological classification?']],
#  [['what is the name of the genus that species are grouped into?']],
#  [['what is the first part of a binomial?']],
#  [['what is the first part of a binomial?']],
#  [['what is the first part of a binomial?']],
#  [['what are extinct species known only from?']],
#  [["what was the name of the term  génos ''?"]],
#  [["what was the name of the term  génos ''?"]],
#  [["what was the name of the term  génos ''?"]],
#  [['what is another name for angiosperms?']],
#  [['what is another name for angiosperms?']],
#  [['what is another name for angiosperms?']],
#  [['what period did the first flowering plants diverged from?']],
#  [['what period did the first flowering plants diverged from?']],
#  [['what period did the first flowering plants diverged from?']],
#  [['what period did the first flowering plants diverged from?']],
#  [['what period did the first flowering plants diverged from?']],
#  [['how long have higher plants lived on land?']],
#  [['how long have higher plants lived on land?']],
#  [['what was the name of the ancient flowering plant?']],
#  [['what was the name of the ancient flowering plant?']],
#  [['what was the name of the ancient flowering plant?']],
#  [['what is the earliest known macrofossil?']],
#  [['what is the earliest known macrofossil?']],
#  [['what is the earliest known macrofossil?']],
#  [['what is the earliest known macrofossil?']],
#  [['what is a dependent territory?']],
#  [['what is a dependent territory?']],
#  [['what is a dependency commonly distinguished from?']],
#  [['what is a dependency commonly distinguished from?']],
#  [['what is a dependency commonly distinguished from?']],
#  [['what are some political entities recognized by?']],
#  [['what are some political entities recognized by?']],
#  [['what are some political entities recognized by?']],
#  [['what are some political entities recognized by?']],
#  [['what are dependent claims without general international recognition listed in?']],
#  [['what are dependent claims without general international recognition listed in?']],
#  [['what are dependent claims without general international recognition listed in?']],
#  [['what is the territory of new zealand?']],
#  [['what is the territory of new zealand?']],
#  [['what was developed by the united states geological survey?']],
#  [['what was developed by the united states geological survey?']],
#  [['what was developed by the united states geological survey?']],
#  [['what was developed by the united states geological survey?']],
#  [['what is the name of the database that the database is part of?']],
#  [['what is the name of the database that the database is part of?']],
#  [['what can the general public make proposals at?']],
#  [['how many countries have access to jstor?']],
#  [['how many countries have access to jstor?']],
#  [['how many countries have access to jstor?']],
#  [['how many countries have access to jstor?']],
#  [['how many countries have access to jstor?']],
#  [['what was the name of the president of python university?']],
#  [['what was the name of the president of python university?']],
#  [['what was the name of the president of python university?']],
#  [['What did Ira Fuchs believe was an increasingly outdated technology?']],
#  [['What did Ira Fuchs believe was an increasingly outdated technology?']],
#  [['What did Ira Fuchs believe was an increasingly outdated technology?']],
#  [['What did Ira Fuchs believe was an increasingly outdated technology?']],
#  [['What did Ira Fuchs believe was an increasingly outdated technology?']],
#  [["when was the  philosophical transactions of the royal society ''?"]],
#  [["when was the  philosophical transactions of the royal society ''?"]],
#  [["when was the  philosophical transactions of the royal society ''?"]],
#  [["when was the  philosophical transactions of the royal society ''?"]],
#  [["when was the  philosophical transactions of the royal society ''?"]],
#  [['what was the name of the nonprofit organization founded in 2003?']],
#  [['what was the name of the nonprofit organization founded in 2003?']],
#  [['what was the name of the nonprofit organization founded in 2003?']],
#  [['how many islands does indonesia have?']],
#  [['how many islands does indonesia have?']],
#  [['how many islands does indonesia have?']],
#  [['how many islands does indonesia have?']],
#  [['how many provinces does indonesia have?']],
#  [['how many provinces does indonesia have?']],
#  [['how many provinces does indonesia have?']],
#  [['how many provinces does indonesia have?']],
#  [['when did the indonesian archipelago begin?']],
#  [['when did the indonesian archipelago begin?']],
#  [['when did the indonesian archipelago begin?']],
#  [['when did the indonesian archipelago begin?']],
#  [['when did the indonesian archipelago begin?']],
#  [['what is the largest ethnic group in indonesia?']],
#  [['what is the largest ethnic group in indonesia?']],
#  [['what is the largest ethnic group in indonesia?']],
#  [['what is the largest ethnic group in indonesia?']],
#  [["who proposed the terms  indunesians ''?"]],
#  [["who proposed the terms  indunesians ''?"]],
#  [["who proposed the terms  indunesians ''?"]],
#  [["who proposed the terms  indunesians ''?"]],
#  [["who proposed the terms  indunesians ''?"]],
#  [['what is a region of land not governed by?']],
#  [['what is a region of land not governed by?']],
#  [['what is the name of the local government area?']],
#  [['what are postal addresses in australia?']],
#  [['what is the territorial government responsible for?']],
#  [['what is the territorial government responsible for?']],
#  [['what is the second unincorporated area of the state?']],
#  [['what is the second unincorporated area of the state?']],
#  [['what is the second unincorporated area of the state?']],
#  [['what is the second unincorporated area of the state?']],
#  [["what is ukraine's sovereign state?"]],
#  [["what is ukraine's sovereign state?"]],
#  [["what is ukraine's sovereign state?"]],
#  [['when was the territory of modern ukraine inhabited?']],
#  [['in what year did ukraine declare itself a neutral state?']],
#  [['in what year did ukraine declare itself a neutral state?']],
#  [['in what year did ukraine declare itself a neutral state?']],
#  [['in what year did ukraine declare itself a neutral state?']],
#  [['what is the diversified economy of ukraine?']],
#  [['what is the diversified economy of ukraine?']],
#  [['what percentage of russians are ukrainians?']],
#  [['what percentage of russians are ukrainians?']],
#  [['what percentage of russians are ukrainians?']],
#  [['what percentage of russians are ukrainians?']],
#  [['what is a large and permanent human settlement?']],
#  [['what is a large and permanent human settlement?']],
#  [['what is a large and permanent human settlement?']],
#  [['what are some of the complex systems that have complex systems?']],
#  [['what is the largest city in the world?']],
#  [['what is the largest city in the world?']],
#  [['what is the largest city in the world?']],
#  [['what is the largest city in the world?']],
#  [['what did the advent of farming encourage hunter-gatherers to abandon?']],
#  [['what did the advent of farming encourage hunter-gatherers to abandon?']],
#  [['what did the advent of farming encourage hunter-gatherers to abandon?']],
#  [['What is the population of Great Britain?']],
#  [['What is the population of Great Britain?']],
#  [['What is the population of Great Britain?']],
#  [['how many staff are in public sector broadcasting?']],
#  [['how many staff are in public sector broadcasting?']],
#  [['how many staff are in public sector broadcasting?']],
#  [['how many staff are in public sector broadcasting?']],
#  [['how many staff are in public sector broadcasting?']],
#  [['when was the bbc world service launched?']],
#  [['when was the bbc world service launched?']],
#  [['when was the bbc world service launched?']],
#  [['when was the bbc world service launched?']],
#  [['what is the name of the bbc worldwide ltd?']],
#  [['what is the name of the bbc worldwide ltd?']],
#  [['what is the name of the bbc worldwide ltd?']],
#  [['what is the name of the bbc worldwide ltd?']],
#  [['what was the name of the famous australian soprano?']],
#  [['what was the name of the famous australian soprano?']],
#  [['what was the name of the famous australian soprano?']],
#  [['what was the name of the famous australian soprano?']],
#  [['what was the name of the famous australian soprano?']],
#  [['what was the name of the consortium of leading wireless receiver manufactures?']],
#  [['what was the name of the consortium of leading wireless receiver manufactures?']],
#  [['what was the name of the consortium of leading wireless receiver manufactures?']],
#  [['what was the name of the consortium of leading wireless receiver manufactures?']],
#  [['what was the name of the consortium of leading wireless receiver manufactures?']],
#  [['what is another name for the bibcode?']],
#  [['what is another name for the bibcode?']],
#  [["who coined the term  bibcode ''?"]],
#  [["who coined the term  bibcode ''?"]],
#  [["who coined the term  bibcode ''?"]],
#  [['how many characters does the code have?']],
#  [['how many characters does the code have?']],
#  [['how many characters does the code have?']],
#  [['how many characters does the code have?']],
#  [['what is the official currency of the united states?']],
#  [['what is the official currency of the united states?']],
#  [['what is the official currency of the united states?']],
#  [['what is the currency most used in international transactions?']],
#  [['what is the currency most used in international transactions?']],
#  [['what is the currency most used in international transactions?']],
#  [['what is the pure silver dollar known as?']],
#  [['what is the pure silver dollar known as?']],
#  [['what is the pure silver dollar known as?']],
#  [['what is the provision of the constitution?']],
#  [['what is the provision of the constitution?']],
#  [['what is the provision of the constitution?']],
#  [['what was the name of the act that authorized the production of various coins?']],
#  [['what was the name of the act that authorized the production of various coins?']],
#  [['what is a type of numbering scheme?']],
#  [['what is a type of numbering scheme?']],
#  [['what is a type of numbering scheme?']],
#  [['what does a closed numbering plan imposes?']],
#  [['how many parts does the north american numbering plan have?']],
#  [['what is the name of the comprehensive numbering plan?']],
#  [['what is the name of the comprehensive numbering plan?']],
#  [['what is the name of the comprehensive numbering plan?']],
#  [['what is the name of the comprehensive numbering plan?']],
#  [['what is the name of the private branch exchange?']],
#  [['what is the name of the private branch exchange?']],
#  [['what is the name of the private branch exchange?']],
#  [['what is one of the eight major taxonomic ranks?']],
#  [['what is one of the eight major taxonomic ranks?']],
#  [['what is one of the eight major taxonomic ranks?']],
#  [['what is one of the eight major taxonomic ranks?']],
#  [['what are the names of the family that are proposed and determined by practicing taxonomists?']],
#  [['what is the naming of families codified by?']],
#  [['who first used the taxonomic term?']],
#  [['who first used the taxonomic term?']],
#  [['who first used the taxonomic term?']],
#  [["who used the word  in his '?"]],
#  [["who used the word  in his '?"]],
#  [["who used the word  in his '?"]],
#  [["who used the word  in his '?"]],
#  [['where is the national library of france located?']],
#  [['where is the national library of france located?']],
#  [['where is the national library of france located?']],
#  [['who founded the national library of france?']],
#  [['who founded the national library of france?']],
#  [['who founded the national library of france?']],
#  [['who founded the national library of france?']],
#  [['who founded the national library of france?']],
#  [['who inherited the library at blois?']],
#  [['who inherited the library at blois?']],
#  [['who inherited the library at blois?']],
#  [['who inherited the library at blois?']],
#  [['who inherited the library at blois?']],
#  [['Where was the Collège de Clermont housed?']],
#  [['Where was the Collège de Clermont housed?']],
#  [['Where was the Collège de Clermont housed?']],
#  [['Where was the Collège de Clermont housed?']],
#  [['Where was the Collège de Clermont housed?']],
#  [['When was the library moved to a more spacious house in Rue Vivienne?']],
#  [['When was the library moved to a more spacious house in Rue Vivienne?']],
#  [['When was the library moved to a more spacious house in Rue Vivienne?']],
#  [['When was the library moved to a more spacious house in Rue Vivienne?']],
#  [['what is the official romanization system?']],
#  [['what is the official romanization system?']],
#  [['what is the official romanization system?']],
#  [['what is the official romanization system?']],
#  [['what is the official romanization system?']],
#  [['when was the hanyu pinyin system developed?']],
#  [['when was the hanyu pinyin system developed?']],
#  [['when was the hanyu pinyin system developed?']],
#  [['when was the hanyu pinyin system developed?']],
#  [["what does the word  '' mean?"]],
#  [["what does the word  '' mean?"]],
#  [['what was the name of the jesuit missionary in 1605?']],
#  [['what was the name of the jesuit missionary in 1605?']],
#  [['what was the name of the jesuit missionary in 1605?']],
#  [['what was the name of the jesuit missionary in 1605?']],
#  [['what was one of the earliest chinese thinkers to relate western alphabets?']],
#  [['what is the standard clock time observed during the period of summer?']],
#  [['what is the standard clock time observed during the period of summer?']],
#  [['what is the standard clock time observed during the period of summer?']],
#  [['what are some names that have been applied to central european summer time?']],
#  [['what are some names that have been applied to central european summer time?']],
#  [['when was european summer time observed?']],
#  [['when was european summer time observed?']],
#  [['when was european summer time observed?']],
#  [['when was european summer time observed?']],
#  [['when was european summer time observed?']],
#  [['what is the name of the countries that generate questions?']],
#  [['when was cest used in portugal?']],
#  [['when was cest used in portugal?']],
#  [['when was the league of nations established?']],
#  [['when was the league of nations established?']],
#  [['when was the league of nations established?']],
#  [['when was the league of nations established?']],
#  [['when was the league of nations established?']],
#  [['when was the united nations charter drafted?']],
#  [['when was the united nations charter drafted?']],
#  [['when was the united nations charter drafted?']],
#  [['when was the united nations charter drafted?']],
#  [['what is the secretary-general office held by?']],
#  [['what is the secretary-general office held by?']],
#  [['what is the secretary-general office held by?']],
#  [['what is the secretary-general office held by?']],
#  [['what is the secretary-general office held by?']],
#  [['in what year did the nobel peace prize take place?']],
#  [['in what year did the nobel peace prize take place?']],
#  [['in what year did the nobel peace prize take place?']],
#  [['in what year did the nobel peace prize take place?']],
#  [['what was the name of the international treaty organizations that had been formed?']],
#  [['what was the name of the international treaty organizations that had been formed?']],
#  [['what was the name of the international treaty organizations that had been formed?']],
#  [['what was the name of the international treaty organizations that had been formed?']],
#  [['what was the name of the international treaty organizations that had been formed?']],
#  [['what are some of the terms used to describe drainage basins?']],
#  [['what are some of the terms used to describe drainage basins?']],
#  [['what is another name for closed drainage basins?']],
#  [['what is another name for closed drainage basins?']],
#  [['what is another name for closed drainage basins?']],
#  [['what are drainage areas delineated to nest into?']],
#  [['what are drainage areas delineated to nest into?']],
#  [['what are drainage areas delineated to nest into?']],
#  [['what are grey areas?']],
#  [['what are grey areas?']],
#  [['what are the three rivers that drain the most water?']],
#  [['what are the three rivers that drain the most water?']],
#  [['what is the capital of ireland?']],
#  [['what is the capital of ireland?']],
#  [['what is the capital of ireland?']],
#  [['what is the capital of ireland?']],
#  [['when was the irish free state created?']],
#  [['when was the irish free state created?']],
#  [['when was the irish free state created?']],
#  [['when was the irish free state created?']],
#  [['when was the irish free state created?']],
#  [['what was the name of the economic policy that resulted in rapid economic growth?']],
#  [['what was the name of the economic policy that resulted in rapid economic growth?']],
#  [['what was the name of the economic policy that resulted in rapid economic growth?']],
#  [['what was the name of the economic policy that resulted in rapid economic growth?']],
#  [['what was the name of the economic policy that resulted in rapid economic growth?']],
#  [['when was the constitution of ireland adopted?']],
#  [['when was the constitution of ireland adopted?']],
#  [['when was the constitution of ireland adopted?']],
#  [['when was the constitution of ireland adopted?']],
#  [['when was the constitution of ireland adopted?']],
#  [["what was the name of the agreement that it used the name  ire ''?"]],
#  [["what was the name of the agreement that it used the name  ire ''?"]],
#  [["what was the name of the agreement that it used the name  ire ''?"]],
#  [["what was the name of the agreement that it used the name  ire ''?"]],
#  [["what was the name of the agreement that it used the name  ire ''?"]],
#  [['how many residents are in chicago?']],
#  [['how many residents are in chicago?']],
#  [['how many residents are in chicago?']],
#  [['how many residents are in chicago?']],
#  [['how many residents are in chicago?']],
#  [['when was chicago incorporated as a city?']],
#  [['when was chicago incorporated as a city?']],
#  [['when was chicago incorporated as a city?']],
#  [['when was chicago incorporated as a city?']],
#  [['how many international and domestic visitors did chicago have?']],
#  [['how many international and domestic visitors did chicago have?']],
#  [['how many international and domestic visitors did chicago have?']],
#  [['who was the first known reference to the site of the current city of chicago?']],
#  [['who was the first known reference to the site of the current city of chicago?']],
#  [['who was the first known reference to the site of the current city of chicago?']],
#  [['who was the first known reference to the site of the current city of chicago?']],
#  [['who was the first known reference to the site of the current city of chicago?']],
#  [['what was the name of the treaty that the united states army built?']],
#  [['what was the name of the treaty that the united states army built?']],
#  [['what was the name of the treaty that the united states army built?']],
#  [['what was the name of the treaty that the united states army built?']],
#  [['what was the name of the treaty that the united states army built?']],
#  [["when was the  encyclopdia britannica '' published?"]],
#  [["when was the  encyclopdia britannica '' published?"]],
#  [["when was the  encyclopdia britannica '' published?"]],
#  [['who was appointed editor in chief?']],
#  [['who was appointed editor in chief?']],
#  [['who was appointed editor in chief?']],
#  [['who was appointed editor in chief?']],
#  [['when was the tenth edition published?']],
#  [['when was the tenth edition published?']],
#  [['when was the tenth edition published?']],
#  [['when was the tenth edition published?']],
#  [['when was the tenth edition published?']],
#  [['what was the first edition of the 1911 edition?']],
#  [["what was the first edition of  ritannica ''?"]],
#  [["what was the first edition of  ritannica ''?"]],
#  [["what was the first edition of  ritannica ''?"]],
#  [["what was the first edition of  ritannica ''?"]],
#  [["what is taiwan's state?"]],
#  [["what is taiwan's state?"]],
#  [["what is taiwan's state?"]],
#  [["what is taiwan's state?"]],
#  [['when was the republic of china established?']],
#  [['when was the republic of china established?']],
#  [['when was the republic of china established?']],
#  [['when was the republic of china established?']],
#  [['when was the republic of china established?']],
#  [['what was the name of the military dictatorship that taiwan changed from?']],
#  [['what was the name of the military dictatorship that taiwan changed from?']],
#  [["When did the ROC assume China's seat?"]],
#  [["When did the ROC assume China's seat?"]],
#  [["When did the ROC assume China's seat?"]],
#  [["When did the ROC assume China's seat?"]],
#  [["When did the ROC assume China's seat?"]],
#  [['when did portuguese sailors sighted the main island?']],
#  [['when did portuguese sailors sighted the main island?']],
#  [['when did portuguese sailors sighted the main island?']],
#  [['when did portuguese sailors sighted the main island?']],
#  [["what is the term for the term  county ''?"]],
#  [["what is the term for the term  county ''?"]],
#  [["what is the term for the term  county ''?"]],
#  [["what is the term for the term  county ''?"]],
#  [['what is the larger unit of a larger unit?']],
#  [['what is the larger unit of a larger unit?']],
#  [["what is another name for  county counties ''?"]],
#  [["what is another name for  county counties ''?"]],
#  [["what is another name for  county counties ''?"]],
#  [["what is another name for  county counties ''?"]],
#  [["what is another name for  county counties ''?"]],
#  [['how many land counties were there in 2008?']],
#  [['how many land counties were there in 2008?']],
#  [['how many land counties were there in 2008?']],
#  [['how many land counties were there in 2008?']],
#  [['how many land counties were there in 2008?']],
#  [["what was the name of the poland's partitioning?"]],
#  [["what was the name of the poland's partitioning?"]],
#  [["what was the name of the poland's partitioning?"]],
#  [['what is a measurement of population per unit?']],
#  [['what is a measurement of population per unit?']],
#  [['what is population divided by?']],
#  [['what is the name of the scientist that identified the scientist?']],
#  [['what is the number of people per unit of area?']],
#  [['what is the number of people per unit of area?']],
#  [["what is the world's population?"]],
#  [["what is the world's population?"]],
#  [['what is a time offset that adds 1 hour?']],
#  [['what is a time offset that adds 1 hour?']],
#  [['what is the associated time in iso 8601?']],
#  [['what are some common censuses?']],
#  [['what are some common censuses?']],
#  [['what is the word for the word latin origin?']],
#  [['what is the name of the united nations population fund?']],
#  [['what is the name of the united nations population fund?']],
#  [['what are modern census data commonly used for?']],
#  [['what are modern census data commonly used for?']],
#  [['what are modern census data commonly used for?']],
#  [['what is the fundamental premise of a census?']],
#  [['what is the fundamental premise of a census?']],
#  [['what is the fundamental premise of a census?']],
#  [['what is the study of mathematics?']],
#  [['what is the study of mathematics?']],
#  [['what can mathematical reasoning provide?']],
#  [['who was the pioneering work of giuseppe peano?']],
#  [['who was the pioneering work of giuseppe peano?']],
#  [['who was the pioneering work of giuseppe peano?']],
#  [['who was the pioneering work of giuseppe peano?']],
#  [['who was the pioneering work of giuseppe peano?']],
#  [['who referred to mathematics as the queen of the sciences?']],
#  [['who referred to mathematics as the queen of the sciences?']],
#  [['who referred to mathematics as the queen of the sciences?']],
#  [['who referred to mathematics as the queen of the sciences?']],
#  [['who referred to mathematics as the queen of the sciences?']],
#  [['what are some of the new mathematical disciplines?']],
#  [['what are some of the new mathematical disciplines?']],
#  [['what is one of the names of time zone?']],
#  [['what is one of the names of time zone?']],
#  [['what is one of the names of time zone?']],
#  [['what is one of the names of time zone?']],
#  [['what is a number of african countries called?']],
#  [['what is the name of the countries that use eastern european time?']],
#  [['what do the following countries use during the winter?']],
#  [['what are some of the countries that are used to refer to eastern european time?']],
#  [['what are some of the countries that are used to refer to eastern european time?']],
#  [['what are some of the countries that are used to refer to eastern european time?']],
#  [["what is canada's most populous province?"]],
#  [["what is canada's most populous province?"]],
#  [["what is canada's most populous province?"]],
#  [['where is ontario bordered?']],
#  [['where is ontario bordered?']],
#  [["where is the great majority of ontario's population located?"]],
#  [["where is the great majority of ontario's population located?"]],
#  [['what is the province named after?']],
#  [['what is the province named after?']],
#  [['what is the province named after?']],
#  [['what is the province of the province?']],
#  [['what is the second largest state in the united states?']],
#  [['what is texas nicknamed?']],
#  [['what is texas nicknamed?']],
#  [['what is texas nicknamed?']],
#  [['what is texas nicknamed?']],
#  [['what is texas nicknamed?']],
#  [["what percentage of texas'land area is desert?"]],
#  [["what percentage of texas'land area is desert?"]],
#  [["what percentage of texas'land area is desert?"]],
#  [["what percentage of texas'land area is desert?"]],
#  [["what percentage of texas'land area is desert?"]],
#  [['what was the name of the first european country to claim the area?']],
#  [['what was the name of the first european country to claim the area?']],
#  [['what was the name of the first european country to claim the area?']],
#  [['what was the name of the first european country to claim the area?']],
#  [['what was the name of the industry that thrived after the civil war?']],
#  [['what was the name of the industry that thrived after the civil war?']],
#  [['what is the principal unit of the administrative division of poland?']],
#  [['what is the principal unit of the administrative division of poland?']],
#  [['what is the principal unit of the administrative division of poland?']],
#  [['what is the principal unit of the administrative division of poland?']],
#  [['what is the name of the town that is administered from the town?']],
#  [['what is the name of the town that is administered from the town?']],
#  [['what is the legislative and controlling body of each gmina?']],
#  [['what is the legislative and controlling body of each gmina?']],
#  [['what are public tasks exercised by?']],
#  [['what are public tasks exercised by?']],
#  [['what are the tasks handed over on?']],
#  [['what are the tasks handed over on?']],
#  [['where is ireland separated from?']],
#  [['where is ireland separated from?']],
#  [['how many live in the republic of ireland?']],
#  [['how many live in the republic of ireland?']],
#  [['how many live in the republic of ireland?']],
#  [['how many extant mammal species are native to ireland?']],
#  [['how many extant mammal species are native to ireland?']],
#  [['when was the earliest evidence of human presence in ireland?']],
#  [['when was the earliest evidence of human presence in ireland?']],
#  [['when was the earliest evidence of human presence in ireland?']],
#  [['when was the earliest evidence of human presence in ireland?']],
#  [['what are some of the sports that the culture of the island shares?']],
#  [['what are some of the sports that the culture of the island shares?']],
#  [['what are some of the sports that the culture of the island shares?']],
#  [["what is another name for a person's full nomenclature?"]],
#  [["what is another name for a person's full nomenclature?"]],
#  [["what is another name for a person's full nomenclature?"]],
#  [['what are special types of given names?']],
#  [['what is the name of the order that is used in most european countries?']],
#  [['what is the name of the order that is used in most european countries?']],
#  [["where is the order  family name - given name '' used?"]],
#  [["where is the order  family name - given name '' used?"]],
#  [["where is the order  family name - given name '' used?"]],
#  [["where is the order  family name - given name '' used?"]],
#  [["where is the order  family name - given name '' used?"]],
#  [['what is the name of the order that can be changed legally in spain?']],
#  [['what is the name of the order that can be changed legally in spain?']],
#  [['what is the name of the order that can be changed legally in spain?']],
#  [['how many states does malaysia have?']],
#  [['how many states does malaysia have?']],
#  [['how many states does malaysia have?']],
#  [['how many states does malaysia have?']],
#  [['how many states does malaysia have?']],
#  [['when was the malayan union restructured?']],
#  [['when was the malayan union restructured?']],
#  [['when was the malayan union restructured?']],
#  [['when was the malayan union restructured?']],
#  [['when was the malayan union restructured?']],
#  [['what is the head of state known as?']],
#  [['what is the head of state known as?']],
#  [['what is the head of state known as?']],
#  [['what is the head of state known as?']],
#  [['what is the head of state known as?']],
#  [["what is malaysia's gdp?"]],
#  [["what is malaysia's gdp?"]],
#  [["what is the name of the word  malaysia ''?"]],
#  [["what is the name of the word  malaysia ''?"]],
#  [['what is a sovereign state in international law?']],
#  [['what is a sovereign state in international law?']],
#  [['what is a sovereign state in international law?']],
#  [['what is the existence of a state?']],
#  [['what are some of the political orders that emerged from feudal europe?']],
#  [['what is the concept of nation-state sovereignty?']],
#  [['what is the concept of nation-state sovereignty?']],
#  [['what is the concept of nation-state sovereignty?']],
#  [['what was the radicalised concept of the world?']],
#  [["what is the name of the word  vowelship ''?"]],
#  [["what is the name of the word  vowelship ''?"]],
#  [["what is the name of the word  vowelship ''?"]],
#  [["what is the name of the word  vowelship ''?"]],
#  [["what is the name of the word  vowelship ''?"]],
#  [['when did the poland local government reforms begin?']],
#  [['when did the poland local government reforms begin?']],
#  [['when did the poland local government reforms begin?']],
#  [['when did the poland local government reforms begin?']],
#  [['what is the population of the new units?']],
#  [['what is the population of the new units?']],
#  [['what is the population of the new units?']],
#  [['what is another name for the elected assembly?']],
#  [['what is another name for the elected assembly?']],
#  [['what is another name for the elected assembly?']],
#  [['what is another name for the elected assembly?']],
#  [['where are the voivode offices located?']],
#  [['where are the voivode offices located?']],
#  [['what is the hong kong special administrative region?']],
#  [['what is the hong kong special administrative region?']],
#  [['what is the hong kong special administrative region?']],
#  [['what is the hong kong special administrative region?']],
#  [['what is the hong kong special administrative region?']],
#  [['when was the first opium war?']],
#  [['when was the first opium war?']],
#  [['when was the first opium war?']],
#  [['when was the first opium war?']],
#  [['when was the first opium war?']],
#  [['what is the principle of hong kong?']],
#  [['what is the principle of hong kong?']],
#  [['what is the principle of hong kong?']],
#  [["what is hong kong's legal tender?"]],
#  [["what is hong kong's legal tender?"]],
#  [["what is hong kong's legal tender?"]],
#  [['what percentage of the population makes use of well-developed public transportation?']],
#  [['what percentage of the population makes use of well-developed public transportation?']],
#  [['what percentage of the population makes use of well-developed public transportation?']],
#  [['what is the name of the british national daily newspaper?']],
#  [['what is the name of the british national daily newspaper?']],
#  [['what is the name of the british national daily newspaper?']],
#  [['what is the name of the british national daily newspaper?']],
#  [['what is the name of the british national daily newspaper?']],
#  [['what is the name of the international websites that the newspaper has?']],
#  [['what is the name of the international websites that the newspaper has?']],
#  [['what is the name of the international websites that the newspaper has?']],
#  [['what is the name of the international websites that the newspaper has?']],
#  [['what is the name of the international websites that the newspaper has?']],
#  [['what was the name of the highest circulation newspapers in the world?']],
#  [['what was the name of the highest circulation newspapers in the world?']],
#  [['what was the name of the highest circulation newspapers in the world?']],
#  [['what was the name of the highest circulation newspapers in the world?']],
#  [['what was the name of the 2014 british press awards?']],
#  [['what was the name of the 2014 british press awards?']],
#  [['what is the paper referred to as?']],
#  [['what is the sole provincial official language?']],
#  [['what is the sole provincial official language?']],
#  [["what is canada's largest province?"]],
#  [["what is canada's largest province?"]],
#  [["what is canada's largest province?"]],
#  [["what is canada's largest province?"]],
#  [["what is canada's largest province?"]],
#  [["What is Quebec's second-most populous province?"]],
#  [["What is Quebec's second-most populous province?"]],
#  [["What is Quebec's second-most populous province?"]],
#  [['when did the house of commons of canada pass a symbolic motion?']],
#  [['when did the house of commons of canada pass a symbolic motion?']],
#  [['when did the house of commons of canada pass a symbolic motion?']],
#  [['what are some sectors of the knowledge economy?']],
#  [['how many players are in ice hockey teams?']],
#  [['how many players are in ice hockey teams?']],
#  [['how many players are in ice hockey teams?']],
#  [['how many players are in ice hockey teams?']],
#  [['what is the official national winter sport of canada?']],
#  [['what is the official national winter sport of canada?']],
#  [['what is the official national winter sport of canada?']],
#  [['what is the official national winter sport of canada?']],
#  [['what is the official national winter sport of canada?']],
#  [['when was the first indoor hockey game played?']],
#  [['when was the first indoor hockey game played?']],
#  [['when was the first indoor hockey game played?']],
#  [['when was the first indoor hockey game played?']],
#  [['when was the first indoor hockey game played?']],
#  [['how many medals have been awarded to the six nations?']],
#  [['how many medals have been awarded to the six nations?']],
#  [['how many medals have been awarded to the six nations?']],
#  [['how many medals have been awarded to the six nations?']],
#  [['how many medals have been awarded to the six nations?']],
#  [['what is ice hockey often called?']],
#  [['what is ice hockey often called?']],
#  [['what is ice hockey often called?']],
#  [['what are some midfielders otherwise known as?']],
#  [['what are some midfielders otherwise known as?']],
#  [['what are some midfielders otherwise known as?']],
#  [['what are some midfielders otherwise known as?']],
#  [['what are midfielders the players who typically travel?']],
#  [['what are midfielders the players who typically travel?']],
#  [['what are midfielders the players who typically travel?']],
#  [['what is the role of central or centre midfielders?']],
#  [['what is the role of central or centre midfielders?']],
#  [['what is the role of central or centre midfielders?']],
#  [['what is the role of central or centre midfielders?']],
#  [['what can a central midfielder drop back to protect?']],
#  [['what can a central midfielder drop back to protect?']],
#  [['what is one of the two deeper midfielders?']],
#  [['what is one of the two deeper midfielders?']],
#  [['what is one of the two deeper midfielders?']],
#  [['what is one of the two deeper midfielders?']],
#  [['what is a file format used to present documents?']],
#  [['what are some proprietary technologies defined by adobe?']],
#  [['what are some proprietary technologies defined by adobe?']],
#  [['what are some proprietary technologies defined by adobe?']],
#  [['what are some proprietary technologies defined by adobe?']],
#  [['what are some proprietary technologies defined by adobe?']],
#  [['what was the name of the iso 32000-2?']],
#  [['what is a page description language run in?']],
#  [['what is a page description language run in?']],
#  [['what is a page description language run in?']],
#  [['what are the three traditional divisions of western history?']],
#  [['what are the three traditional divisions of western history?']],
#  [['what are the three traditional divisions of western history?']],
#  [['what are the three traditional divisions of western history?']],
#  [['what was the name of the law code that was rediscovered in northern italy?']],
#  [['what was the name of the law code that was rediscovered in northern italy?']],
#  [['what was the name of the law code that was rediscovered in northern italy?']],
#  [['what was the name of the law code that was rediscovered in northern italy?']],
#  [['what was the name of the law code that was rediscovered in northern italy?']],
#  [['what was the political structure of peasants?']],
#  [['what was the political structure of peasants?']],
#  [['what was the political structure of peasants?']],
#  [['what was the political structure of peasants?']],
#  [['what was the political structure of peasants?']],
#  [['when did the black death kill about a third of europeans?']],
#  [['when did the black death kill about a third of europeans?']],
#  [['when did the black death kill about a third of europeans?']],
#  [['what is one of the three major periods in the most enduring scheme?']],
#  [['what is one of the three major periods in the most enduring scheme?']],
#  [['what is the kingdom of thailand?']],
#  [['what is the kingdom of thailand?']],
#  [['what is the kingdom of thailand?']],
#  [['what is the kingdom of thailand?']],
#  [['what is the kingdom of thailand?']],
#  [["what is thailand's constitutional monarchy?"]],
#  [["what is thailand's constitutional monarchy?"]],
#  [["what is thailand's constitutional monarchy?"]],
#  [["what is thailand's constitutional monarchy?"]],
#  [["what is thailand's constitutional monarchy?"]],
#  [['what are the leading sectors of the economy?']],
#  [['what are the leading sectors of the economy?']],
#  [['when was thailand renamed?']],
#  [['when was thailand renamed?']],
#  [['when was thailand renamed?']],
#  [['when was thailand renamed?']],
#  [["what does the word  thai '' mean?"]],
#  [["what does the word  thai '' mean?"]],
#  [["what does the word  thai '' mean?"]],
#  [["what does the word  thai '' mean?"]],
#  [["what does the word  thai '' mean?"]],
#  [["what is serbia's sovereign state?"]],
#  [["what is serbia's sovereign state?"]],
#  [["what is serbia's sovereign state?"]],
#  [["what is serbia's sovereign state?"]],
#  [["what is serbia's sovereign state?"]],
#  [['when did the serbian kingdom reach its peak?']],
#  [['when did the serbian kingdom reach its peak?']],
#  [['when did the serbian kingdom reach its peak?']],
#  [['when did the serbian kingdom reach its peak?']],
#  [['when did the serbian kingdom reach its peak?']],
#  [['what is serbia a member of?']],
#  [['what is serbia a member of?']],
#  [['what is serbia a member of?']],
#  [['what is the total area of the country?']],
#  [['what is the total area of the country?']],
#  [['what is the total area of the country?']],
#  [['what is the total area of the country?']],
#  [['what are the northern third of the country?']],
#  [['what are the northern third of the country?']],
#  [['what are the northern third of the country?']],
#  [['what is the name of the south american country?']],
#  [['what is the name of the desert in northern chile?']],
#  [['what is the name of the desert in northern chile?']],
#  [['what is the name of the desert in northern chile?']],
#  [['when did chile become independent from spain?']],
#  [['what is the founding member of the united nations?']],
#  [['what is the founding member of the united nations?']],
#  [['who ruled the valley of the aconcagua?']],
#  [['who ruled the valley of the aconcagua?']],
#  [['who ruled the valley of the aconcagua?']],
#  [['who ruled the valley of the aconcagua?']],
#  [['who ruled the valley of the aconcagua?']],
#  [['who founded the modern-day democratic party?']],
#  [['who founded the modern-day democratic party?']],
#  [['who founded the modern-day democratic party?']],
#  [['who founded the modern-day democratic party?']],
#  [['who founded the modern-day democratic party?']],
#  [['who was the presidential candidate in the 1890s?']],
#  [['who was the presidential candidate in the 1890s?']],
#  [['who was the presidential candidate in the 1890s?']],
#  [['who was the presidential candidate in the 1890s?']],
#  [['When did the New Deal Coalition begin?']],
#  [['what is the house democratic caucus composed of?']],
#  [['what is the name of the party that the party has united with?']],
#  [['what is the name of the party that the party has united with?']],
#  [['what is the name of the party that the party has united with?']],
#  [['how many residents are in the metropolitan city?']],
#  [['how many residents are in the metropolitan city?']],
#  [['when was the founding of rome?']],
#  [['when was the founding of rome?']],
#  [['when was the founding of rome?']],
#  [['when was the founding of rome?']],
#  [['when was the founding of rome?']],
#  [['what was the capital of the papal states?']],
#  [['what was the capital of the papal states?']],
#  [['what was the capital of the papal states?']],
#  [['when did nicholas v die?']],
#  [['when did nicholas v die?']],
#  [['when did nicholas v die?']],
#  [['when did nicholas v die?']],
#  [['when did nicholas v die?']],
#  [["what is the name of the world's most visited tourist destinations?"]],
#  [["what is the name of the world's most visited tourist destinations?"]],
#  [["what is the name of the world's most visited tourist destinations?"]],
#  [["what is the name of the world's most visited tourist destinations?"]],
#  [["what is the name of the world's most visited tourist destinations?"]],
#  [['what is a single or record single?']],
#  [['what is a single or record single?']],
#  [['what is the concept of a single for an album?']],
#  [['what is the concept of a single for an album?']],
#  [['what is the name of the biggest digital music distributor?']],
#  [['what is the name of the biggest digital music distributor?']],
#  [['what was the range of playback speeds?']],
#  [['what was the range of playback speeds?']],
#  [['what was chosen as the standard because of the introduction of the electrically powered?']],
#  [['what was chosen as the standard because of the introduction of the electrically powered?']],
#  [['what is a time offset that subtracts five hours?']],
#  [['what is a time offset that subtracts five hours?']],
#  [['what is a time offset that subtracts five hours?']],
#  [['what is a time offset that subtracts five hours?']],
#  [['what is the name of the republic of singapore?']],
#  [['what is the name of the republic of singapore?']],
#  [['what is the name of the republic of singapore?']],
#  [['what is the name of the republic of singapore?']],
#  [['who founded colonial singapore?']],
#  [['who founded colonial singapore?']],
#  [['who founded colonial singapore?']],
#  [['who founded colonial singapore?']],
#  [['who founded colonial singapore?']],
#  [["what is shanghai's name?"]],
#  [["what is shanghai's name?"]],
#  [["what is shanghai's name?"]],
#  [["what is shanghai's name?"]],
#  [['what percentage of homes are owner occupied?']],
#  [['what percentage of homes are owner occupied?']],
#  [['what percentage of homes are owner occupied?']],
#  [['what percentage of homes are owner occupied?']],
#  [['what percentage of homes are owner occupied?']],
#  [["what is singapore's parliamentary republic?"]],
#  [["what is singapore's parliamentary republic?"]],
#  [["what is singapore's parliamentary republic?"]],
#  [["what is singapore's parliamentary republic?"]],
#  [["what is singapore's parliamentary republic?"]],
#  [['what is the state located in the northern and mid-atlantic regions?']],
#  [['what is the state located in the northern and mid-atlantic regions?']],
#  [['what is the state located in the northern and mid-atlantic regions?']],
#  [['what is the state located in the northern and mid-atlantic regions?']],
#  [['what is the state capital?']],
#  [['what is the state capital?']],
#  [['what is the state capital?']],
#  [['what is the state capital?']],
#  [['what is the state capital?']],
#  [['what was the name of the royal land grant in 1681?']],
#  [['what was the name of the royal land grant in 1681?']],
#  [['what was the name of the royal land grant in 1681?']],
#  [['what was the name of the royal land grant in 1681?']],
#  [['what was the name of the royal land grant in 1681?']],
#  [['what is the 33rd largest state in the united states?']],
#  [['what is the 33rd largest state in the united states?']],
#  [['what is the 33rd largest state in the united states?']],
#  [['what is the name of the line of the state?']],
#  [['what is the name of the line of the state?']],
#  [['what is the name of the line of the state?']],
#  [['what is the name of the line of the state?']],
#  [['how many species of moth are there?']],
#  [['how many species of moth are there?']],
#  [['how many species of moth are there?']],
#  [['what are the two groups of the lepidoptera?']],
#  [['what are the divisions named by?']],
#  [['what are the divisions named by?']],
#  [['what are the divisions named by?']],
#  [["what does the modern english word  mohe '' mean?"]],
#  [["what does the modern english word  mohe '' mean?"]],
#  [['what are some moth caterpillars?']],
#  [['what is an international standard for language codes?']],
#  [['what is an international standard for language codes?']],
#  [['what is the iso 639-2 alpha-3 codes?']],
#  [['what is the iso 639-2 alpha-3 codes?']],
#  [['what is the iso 639-2 alpha-3 codes?']],
#  [['what is iso 639-3 intended for?']],
#  [['what is iso 639-3 intended for?']],
#  [['what does iso 639-3 provide?']],
#  [['how many entries does the standard have?']],
#  [['how many entries does the standard have?']],
#  [['how many entries does the standard have?']],
#  [['how many entries does the standard have?']],
#  [['when was the republican party founded?']],
#  [['when was the republican party founded?']],
#  [['when was the republican party founded?']],
#  [['when was the republican party founded?']],
#  [['when was abraham lincoln assassinated?']],
#  [['when was abraham lincoln assassinated?']],
#  [['when was abraham lincoln assassinated?']],
#  [['when was abraham lincoln assassinated?']],
#  [['when was abraham lincoln assassinated?']],
#  [["what is the republican party's current ideology?"]],
#  [["what is the republican party's current ideology?"]],
#  [["what is the republican party's current ideology?"]],
#  [['how many partisan state legislative chambers have republicans?']],
#  [['how many partisan state legislative chambers have republicans?']],
#  [['how many partisan state legislative chambers have republicans?']],
#  [['what was the name of the republican national committee?']],
#  [['what was the name of the republican national committee?']],
#  [["what is the world's main authority on the conservation status?"]],
#  [["what is the world's main authority on the conservation status?"]],
#  [["what is the world's main authority on the conservation status?"]],
#  [["what is the world's main authority on the conservation status?"]],
#  [["what is the world's main authority on the conservation status?"]],
#  [['what is the red list set upon?']],
#  [['what is the red list set upon?']],
#  [['what is the red list set upon?']],
#  [['what is the red list set upon?']],
#  [['what is the red list set upon?']],
#  [['what is the name of the research division of london?']],
#  [['what is the name of the research division of london?']],
#  ...]
